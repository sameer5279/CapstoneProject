# %% [markdown]
# <a href="https://colab.research.google.com/github/sameer5279/CapstoneProject/blob/main/nitttr_assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# loading csv File
file_path = '/content/drive/MyDrive/nitttr/pp2018.csv'
df=pd.read_csv(file_path)

# %%
df.shape
# Out:
# (1024431, 16)

# %% [markdown]
# Q1. Create a DataFrame using a Dictionary/any csv file/ any json file etc.

# %%
df.head
# Out:
# <bound method NDFrame.head of          {666758D7-43A9-3363-E053-6B04A8C0D74E}  405000  2018-01-25 00:00  \
# 0        {666758D7-43AA-3363-E053-6B04A8C0D74E}  315000  2018-01-23 00:00
# 1        {666758D7-43AD-3363-E053-6B04A8C0D74E}  165000  2018-01-19 00:00
# 2        {666758D7-43B0-3363-E053-6B04A8C0D74E}  370000  2018-01-22 00:00
# 3        {666758D7-43B3-3363-E053-6B04A8C0D74E}  320000  2018-01-19 00:00
# 4        {666758D7-43B4-3363-E053-6B04A8C0D74E}  180000  2018-01-31 00:00
# ...                                         ...     ...               ...
# 1024426  {80E1AA98-9F64-7BF8-E053-6C04A8C00BF2}  382500  2018-12-10 00:00
# 1024427  {80E1AA98-9F67-7BF8-E053-6C04A8C00BF2}  394000  2018-12-20 00:00
# 1024428  {80E1AA98-9F69-7BF8-E053-6C04A8C00BF2}  350000  2018-12-14 00:00
# 1024429  {80E1AA98-9F6A-7BF8-E053-6C04A8C00BF2}  346000  2018-12-07 00:00
# 1024430  {80E1AA98-9F6B-7BF8-E053-6C04A8C00BF2}  348000  2018-12-11 00:00
#
# ...

# %%
df.head()
# Out:
#    {666758D7-43A9-3363-E053-6B04A8C0D74E}  405000  2018-01-25 00:00  WR15 8LH  \
# 0  {666758D7-43AA-3363-E053-6B04A8C0D74E}  315000  2018-01-23 00:00   SY7 8QA
# 1  {666758D7-43AD-3363-E053-6B04A8C0D74E}  165000  2018-01-19 00:00   SY1 2BF
# 2  {666758D7-43B0-3363-E053-6B04A8C0D74E}  370000  2018-01-22 00:00   SY8 4DF
# 3  {666758D7-43B3-3363-E053-6B04A8C0D74E}  320000  2018-01-19 00:00  TF10 7ET
# 4  {666758D7-43B4-3363-E053-6B04A8C0D74E}  180000  2018-01-31 00:00   SY3 0NQ
#
#    D  N  F RAMBLERS WAY Unnamed: 8        Unnamed: 9          BORASTON  \
# 0  D  N  F  MONT CENISE        NaN               NaN              CLUN
# 1  T  Y  F           42        NaN        PENSON WAY               NaN
# 2  D  N  F   WILLOW HEY        NaN               NaN  ASHFORD CARBONEL
# 3  D  N  F            3        NaN  PRINCESS GARDENS               NaN
# 4  S  N  F           79        NaN     LYTHWOOD ROAD      BAYSTON HILL
#
#   TENBURY WELLS  SHROPSHIRE SHROPSHIRE.1  A A.1
# ...

# %% [markdown]
# Q2.Remove the column having more than 4 null values.

# %%
#drop all rows with any NaN and NaT values
df1 = df.dropna()
print(df1)
# Out:
#          {666758D7-43A9-3363-E053-6B04A8C0D74E}   405000  2018-01-25 00:00  \
# 35       {666758D7-4627-3363-E053-6B04A8C0D74E}   150000  2018-02-16 00:00
# 42       {666758D7-4632-3363-E053-6B04A8C0D74E}   380000  2018-02-16 00:00
# 53       {666758D7-4640-3363-E053-6B04A8C0D74E}   310000  2018-02-13 00:00
# 55       {666758D7-4647-3363-E053-6B04A8C0D74E}   237000  2018-02-21 00:00
# 63       {666758D7-3F84-3363-E053-6B04A8C0D74E}   235000  2018-01-02 00:00
# ...                                         ...      ...               ...
# 1023954  {80E1AA98-A63C-7BF8-E053-6C04A8C00BF2}  1900000  2018-08-15 00:00
# 1023956  {80E1AA98-A63E-7BF8-E053-6C04A8C00BF2}   525000  2018-08-09 00:00
# 1023958  {80E1AA98-A641-7BF8-E053-6C04A8C00BF2}  1175000  2018-08-01 00:00
# 1024093  {80E1AA98-B0D2-7BF8-E053-6C04A8C00BF2}   610000  2018-12-19 00:00
# 1024169  {80E1AA98-B591-7BF8-E053-6C04A8C00BF2}   320000  2018-11-06 00:00
#
# ...

# %% [markdown]
# Q3.Display the mean of any numerical column A in your DataFrame

# %% [markdown]
# **describe()**
# This method gives the overall descriptive summary of the dataframe. This works only for numerical columns

# %%
df.describe()
# Out:
#              405000
# count  1.024431e+06
# mean   3.502376e+05
# std    1.883952e+06
# min    1.000000e+00
# 25%    1.450000e+05
# 50%    2.300000e+05
# 75%    3.550000e+05
# max    5.692000e+08

# %% [markdown]
# Q4.	Fill the missing values in column A with this mean value assuming no outliers are present in that column.

# %%
# Lets fill the missing values with the value -999
df['BORASTON'].fillna('Not Present',inplace = True)

# %%
df.head()
# Out:
#    {666758D7-43A9-3363-E053-6B04A8C0D74E}  405000  2018-01-25 00:00  WR15 8LH  \
# 0  {666758D7-43AA-3363-E053-6B04A8C0D74E}  315000  2018-01-23 00:00   SY7 8QA
# 1  {666758D7-43AD-3363-E053-6B04A8C0D74E}  165000  2018-01-19 00:00   SY1 2BF
# 2  {666758D7-43B0-3363-E053-6B04A8C0D74E}  370000  2018-01-22 00:00   SY8 4DF
# 3  {666758D7-43B3-3363-E053-6B04A8C0D74E}  320000  2018-01-19 00:00  TF10 7ET
# 4  {666758D7-43B4-3363-E053-6B04A8C0D74E}  180000  2018-01-31 00:00   SY3 0NQ
#
#    D  N  F RAMBLERS WAY Unnamed: 8        Unnamed: 9          BORASTON  \
# 0  D  N  F  MONT CENISE        NaN               NaN              CLUN
# 1  T  Y  F           42        NaN        PENSON WAY       Not Present
# 2  D  N  F   WILLOW HEY        NaN               NaN  ASHFORD CARBONEL
# 3  D  N  F            3        NaN  PRINCESS GARDENS       Not Present
# 4  S  N  F           79        NaN     LYTHWOOD ROAD      BAYSTON HILL
#
#   TENBURY WELLS  SHROPSHIRE SHROPSHIRE.1  A A.1
# ...

# %% [markdown]
# Q5.Display all the column labels of your dataset

# %%
# iterating the columns
for col in df.columns:
    print(col)
# Out:
# {666758D7-43A9-3363-E053-6B04A8C0D74E}
# 405000
# 2018-01-25 00:00
# WR15 8LH
# D
# N
# F
# RAMBLERS WAY
# Unnamed: 8
# Unnamed: 9
# BORASTON
# TENBURY WELLS
# SHROPSHIRE
# SHROPSHIRE.1
# A
# A.1

# %% [markdown]
# Q6.Sort the DataFrame based on a particular numerical column in     descending order

# %%
#Sort values in descending order
df.sort_values('BORASTON', ascending=False)
# Out:
#          {666758D7-43A9-3363-E053-6B04A8C0D74E}  405000  2018-01-25 00:00  \
# 536789   {773788C2-FDF4-2CE4-E053-6C04A8C05E57}  175000  2018-08-24 00:00
# 552260   {75050A85-7BFB-9A88-E053-6B04A8C02390}  195000  2018-07-27 00:00
# 572131   {75050A85-7D2E-9A88-E053-6B04A8C02390}  220000  2018-08-15 00:00
# 518939   {773788C3-00F4-2CE4-E053-6C04A8C05E57}  235000  2018-08-22 00:00
# 1013964  {7E86B6FB-2A1D-458C-E053-6B04A8C0C84C}  210000  2018-11-29 00:00
# ...                                         ...     ...               ...
# 197284   {666758D6-FD24-3363-E053-6B04A8C0D74E}  450000  2018-01-25 00:00
# 546532   {68FEB20B-A7F6-38DA-E053-6C04A8C051AE}  187000  2018-03-02 00:00
# 23962    {79A74E21-C667-1289-E053-6B04A8C01627}  155000  2018-09-24 00:00
# 735221   {64342BFE-7360-422C-E053-6C04A8C0FB8A}  295000  2018-01-25 00:00
# 917931   {773788C2-D4E7-2CE4-E053-6C04A8C05E57}  229500  2018-08-30 00:00
#
#          WR15 8LH  D  N  F    RAMBLERS WAY Unnamed: 8      Unnamed: 9  \
# ...
